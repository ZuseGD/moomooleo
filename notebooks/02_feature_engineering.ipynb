# %% [markdown]
# # Feature Engineering — Leo CM Cup
#
# This notebook loads the cleaned dataset and creates reusable feature columns
# (e.g., normalized roles / styles) that can be used by the analysis notebooks.

# %%
# Core libraries
import pandas as pd
import numpy as np
from pathlib import Path
import sys
sys.path.append("../scripts")
from cm_rounds_utils import normalize_role, normalize_style

CLEANED_PATH = Path("/workspaces/moomooleo/data/cleaned/leo_cm_cleaned.csv")
FEATURE_PATH = Path("/workspaces/moomooleo/data/cleaned/leo_cm_features.csv")

df = pd.read_csv(CLEANED_PATH)
print("Loaded cleaned data:", df.shape)
df.head()
# Out:
# Loaded cleaned data: (1490, 63)
#                  Timestamp   Player IGN           CM Group  \
# 0  2025-10-30 05:42:28.475    Pharaday   Graded (No Limit)
# 1  2025-10-29 21:55:35.958         Ryan  Graded (No Limit)
# 2  2025-10-28 21:03:08.629        Ramen  Graded (No Limit)
# 3  2025-10-28 17:32:17.479  Jackenstein  Graded (No Limit)
# 4  2025-11-09 12:23:05.233         Cien  Graded (No Limit)
#
#   Kitasan Black LB in Account (Non-borrow)  \
# 0                                      MLB
# 1                                      1LB
# 2                                      3LB
# 3                                      NaN
# 4                                      3LB
#
#   Super Creek LB in Account (Non-borrow) Select a round to fill data  \
# 0                                    2LB                  End Survey
# 1                                    NaN                  End Survey
# 2                                    NaN                  End Survey
# 3                                    0LB                  End Survey
# 4                                    0LB                  End Survey
#
#           R1D1 - Uma 1                   R1D1 - Uma 1 Role  \
# 0                  NaN                                 NaN
# 1            Seiun Sky  Ace (Winner, Tanks, Recycled Aces)
# 2  Maruzensky (Summer)  Ace (Winner, Tanks, Recycled Aces)
# 3            Gold Ship  Ace (Winner, Tanks, Recycled Aces)
# 4            Oguri Cap  Ace (Winner, Tanks, Recycled Aces)
#
#   R1D1 - Uma 1 Running Style   R1D1 - Uma 2  ...  \
# 0                        NaN            NaN  ...
# 1               Front Runner  Agnes Tachyon  ...
# 2               Front Runner   Grass Wonder  ...
# 3                 End Closer  Agnes Tachyon  ...
# 4                Pace Chaser   Grass Wonder  ...
#
#                   FINALS - Uma 1 Role FINALS - Uma 1 Running Style  \
# 0                                 NaN                          NaN
# 1  Ace (Winner, Tanks, Recycled Aces)                 Front Runner
# 2  Ace (Winner, Tanks, Recycled Aces)                 Front Runner
# 3  Ace (Winner, Tanks, Recycled Aces)                   End Closer
# 4  Ace (Winner, Tanks, Recycled Aces)                  Pace Chaser
#
#    FINALS - Uma 2                 FINALS - Uma 2 Role  \
# 0             NaN                                 NaN
# 1   Agnes Tachyon  Ace (Winner, Tanks, Recycled Aces)
# 2    Grass Wonder                              Hybrid
# 3   Agnes Tachyon  Ace (Winner, Tanks, Recycled Aces)
# 4  Symboli Rudolf                            Debuffer
#
#   FINALS - Uma 2 Running Style  FINALS - Uma 3  \
# 0                          NaN             NaN
# 1                  Pace Chaser     Mejiro Ryan
# 2                  Late Surger       Gold Ship
# 3                  Pace Chaser    Grass Wonder
# 4                   End Closer    Grass Wonder
#
#                   FINALS - Uma 3 Role FINALS - Uma 3 Running Style  \
# 0                                 NaN                          NaN
# 1                     Aoharu Made Ace                  Late Surger
# 2  Ace (Winner, Tanks, Recycled Aces)                   End Closer
# 3                            Debuffer                   End Closer
# 4                            Debuffer                   End Closer
#
#   FINALS RESULTS How much have you spent on the game so far? (EUR/USD)
# 0            NAN                                            $1000++
# 1            2ND                                                F2P
# 2            1ST                                            $1-$100
# 3            1ST                                                F2P
# 4            1ST                                          $101-$500
#
# [5 rows x 63 columns]

# %%
# Example feature engineering:
# Normalize any *Role and *Running Style columns if they exist.
role_cols = [c for c in df.columns if 'Role' in c]
style_cols = [c for c in df.columns if 'Running Style' in c or 'Running style' in c]

print("Role-like columns:", role_cols)
print("Style-like columns:", style_cols)

for c in role_cols:
    new_c = c + " (Norm)"
    df[new_c] = df[c].apply(normalize_role)

for c in style_cols:
    new_c = c + " (Norm)"
    df[new_c] = df[c].apply(normalize_style)

df.head()
# Out:
# Role-like columns: ['R1D1 - Uma 1 Role', 'R1D1 - Uma 2 Role', 'R1D1 - Uma 3 Role', 'R1D2 - Uma 1 Role', 'R1D2 - Uma 2 Role', 'R1D2 - Uma 3 Role', 'R2D1 - Uma 1 Role', 'R2D1 - Uma 2 Role', 'R2D1 - Uma 3 Role', 'R2D2 - Uma 1 Role', 'R2D2 - Uma 2 Role', 'R2D2 - Uma 3 Role', 'FINALS - Uma 1 Role', 'FINALS - Uma 2 Role', 'FINALS - Uma 3 Role']
# Style-like columns: ['R1D1 - Uma 1 Running Style', 'R1D1 - Uma 2 Running Style', 'R1D1 - Uma 3 Running Style', 'R1D2 - Uma 1 Running Style', 'R1D2 - Uma 2 Running Style', 'R1D2 - Uma 3 Running Style', 'R2D1 - Uma 1 Running Style', 'R2D1 - Uma 2 Running Style', 'R2D1 - Uma 3 Running Style', 'R2D2 - Uma 1 Running Style', 'R2D2 - Uma 2 Running Style', 'R2D2 - Uma 3 Running Style', 'FINALS - Uma 1 Running Style', 'FINALS - Uma 2 Running Style', 'FINALS - Uma 3 Running Style']
#                  Timestamp   Player IGN           CM Group  \
# 0  2025-10-30 05:42:28.475    Pharaday   Graded (No Limit)
# 1  2025-10-29 21:55:35.958         Ryan  Graded (No Limit)
# 2  2025-10-28 21:03:08.629        Ramen  Graded (No Limit)
# 3  2025-10-28 17:32:17.479  Jackenstein  Graded (No Limit)
# 4  2025-11-09 12:23:05.233         Cien  Graded (No Limit)
#
#   Kitasan Black LB in Account (Non-borrow)  \
# 0                                      MLB
# 1                                      1LB
# 2                                      3LB
# 3                                      NaN
# 4                                      3LB
#
#   Super Creek LB in Account (Non-borrow) Select a round to fill data  \
# 0                                    2LB                  End Survey
# 1                                    NaN                  End Survey
# 2                                    NaN                  End Survey
# 3                                    0LB                  End Survey
# 4                                    0LB                  End Survey
#
#           R1D1 - Uma 1                   R1D1 - Uma 1 Role  \
# 0                  NaN                                 NaN
# 1            Seiun Sky  Ace (Winner, Tanks, Recycled Aces)
# 2  Maruzensky (Summer)  Ace (Winner, Tanks, Recycled Aces)
# 3            Gold Ship  Ace (Winner, Tanks, Recycled Aces)
# 4            Oguri Cap  Ace (Winner, Tanks, Recycled Aces)
#
#   R1D1 - Uma 1 Running Style   R1D1 - Uma 2  ...  \
# 0                        NaN            NaN  ...
# 1               Front Runner  Agnes Tachyon  ...
# 2               Front Runner   Grass Wonder  ...
# 3                 End Closer  Agnes Tachyon  ...
# 4                Pace Chaser   Grass Wonder  ...
#
#   R1D2 - Uma 3 Running Style (Norm) R2D1 - Uma 1 Running Style (Norm)  \
# 0                               NaN                               NaN
# 1                        End Closer                      Front Runner
# 2                        End Closer                      Front Runner
# 3                        End Closer                        End Closer
# 4                        End Closer                       Pace Chaser
#
#   R2D1 - Uma 2 Running Style (Norm) R2D1 - Uma 3 Running Style (Norm)  \
# 0                               NaN                               NaN
# 1                       Pace Chaser                        End Closer
# 2                       Late Surger                        End Closer
# 3                       Pace Chaser                        End Closer
# 4                        End Closer                        End Closer
#
#   R2D2 - Uma 1 Running Style (Norm)  R2D2 - Uma 2 Running Style (Norm)  \
# 0                               NaN                                NaN
# 1                      Front Runner                        Pace Chaser
# 2                      Front Runner                        Late Surger
# 3                        End Closer                        Pace Chaser
# 4                       Pace Chaser                         End Closer
#
#    R2D2 - Uma 3 Running Style (Norm) FINALS - Uma 1 Running Style (Norm)  \
# 0                                NaN                                 NaN
# 1                         End Closer                        Front Runner
# 2                         End Closer                        Front Runner
# 3                         End Closer                          End Closer
# 4                         End Closer                         Pace Chaser
#
#   FINALS - Uma 2 Running Style (Norm) FINALS - Uma 3 Running Style (Norm)
# 0                                 NaN                                 NaN
# 1                         Pace Chaser                         Late Surger
# 2                         Late Surger                          End Closer
# 3                         Pace Chaser                          End Closer
# 4                          End Closer                          End Closer
#
# [5 rows x 93 columns]

# %%
# Save engineered feature table
FEATURE_PATH.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(FEATURE_PATH, index=False)
print(f"Feature-augmented data saved to: {FEATURE_PATH.resolve()}")
# Out:
# Feature-augmented data saved to: /workspaces/moomooleo/data/cleaned/leo_cm_features.csv
