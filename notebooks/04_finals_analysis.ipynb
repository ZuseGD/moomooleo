# %% [markdown]
# # CM4 Analysis — Finals Breakdown
#
# This notebook analyzes Finals performance based on:
# - Uma appearances
# - Win rates
# - Role archetypes
# - Debuffer influence
# - Meta share vs WR (bubble chart)
# - Kitasan LB correlation
#
# Inputs:
# - Cleaned dataset (data/cleaned/cm4_clean.csv)
#
# Outputs:
# - Finals visualizations (outputs/figures/)
# - Finals summary tables (outputs/summary_excel/)
